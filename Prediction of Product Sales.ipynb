# %%
# Project Title: (Prediction of Product Sales).

# %%
- Author: "Ahmad Da'na"
# Out:
#   File "<ipython-input-7-b6810d0b99d0>", line 1
#     - Author: "Ahmad Da'na"
#     ^
# SyntaxError: illegal target for annotation

# %%
## "Project Overview"
## "Load and Inspect Data"
## "Clean Data"
## "Exploratory Data Analysis"
## "Feature Inspection"
